# %% [markdown]
# <a href="https://colab.research.google.com/github/salshafi/COMP100-Programming1-Python/blob/main/Creating_Reading_Writinf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Lesson 1: Creating, Reading and Writing

# %% [markdown]
# ## Lesson 1: Creating, Reading and Writing

# %% [markdown]
# **Introduction**
# In this ,icro-course, you'll learn all about pandas, the ost popular Python library for Data analysis.
#
# **Getting Started**
# To use Pandas, you'll typically start with the following line of code.
# inport pandas as pd
#
# **Creating data**
# There are two core objects in pandas: the **DataFrame** and the **Series**.
#
# **DataFrame**
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row(or record) and a column.
#
# ## Lesson 1: Creating, Reading and Writing (1/6)
#
# - DataFrame = table (rows + columns)
# - Series = single column (like one column pulled out of a DataFrame)
# - A DataFrame is basically several Series "glued together"

# %%
import pandas as pd
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})

# %%
# series - a single column of data
pd.Series([1, 2, 3, 4, 5])

# %% [markdown]
# # New Section
